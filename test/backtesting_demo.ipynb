# %%
from datetime import datetime

from vnpy.trader.optimize import OptimizationSetting
from vnpy_ctastrategy.backtesting import BacktestingEngine
from vnpy_ctastrategy.strategies.atr_rsi_strategy import AtrRsiStrategy

# %%
engine = BacktestingEngine()
engine.set_parameters(
    vt_symbol="600941.SSE",
    interval="d",
    start=datetime(2022, 4, 1),
    end=datetime(2025, 4, 25),
    rate=0.3/10000,
    slippage=0.2,
    size=300,
    pricetick=0.2,
    capital=1_000_000,
)
engine.add_strategy(AtrRsiStrategy, {})

# %%
engine.load_data()
engine.run_backtesting()
df = engine.calculate_result()
engine.calculate_statistics()
engine.show_chart()
# Out:
# 2025-04-26 23:57:09.775049	开始加载历史数据
# 2025-04-26 23:57:09.775049	加载进度：# [0%]
# 2025-04-26 23:57:09.804057	加载进度：## [10%]
# 2025-04-26 23:57:09.806058	加载进度：### [20%]
# 2025-04-26 23:57:09.808058	加载进度：#### [30%]
# 2025-04-26 23:57:09.810058	加载进度：##### [40%]
# 2025-04-26 23:57:09.812059	加载进度：###### [50%]
# 2025-04-26 23:57:09.814059	加载进度：####### [60%]
# 2025-04-26 23:57:09.816060	加载进度：######## [70%]
# 2025-04-26 23:57:09.818060	加载进度：######### [80%]
# 2025-04-26 23:57:09.820061	加载进度：########## [90%]
# 2025-04-26 23:57:09.823061	历史数据加载完成，数据量：743
# 2025-04-26 23:57:09.823061	策略初始化完成
# 2025-04-26 23:57:09.823061	开始回放历史数据
# 2025-04-26 23:57:09.824062	回放进度：= [0%]
# 2025-04-26 23:57:09.825062	回放进度：== [10%]
# 2025-04-26 23:57:09.826062	回放进度：=== [20%]
# 2025-04-26 23:57:09.827062	回放进度：==== [30%]
# 2025-04-26 23:57:09.828063	回放进度：===== [40%]
# 2025-04-26 23:57:09.829063	回放进度：====== [50%]
# 2025-04-26 23:57:09.830063	回放进度：======= [60%]
# 2025-04-26 23:57:09.831063	回放进度：======== [70%]
# 2025-04-26 23:57:09.832064	回放进度：========= [80%]
# 2025-04-26 23:57:09.833077	回放进度：========== [90%]
# 2025-04-26 23:57:09.833077	回放进度：=========== [100%]
# 2025-04-26 23:57:09.833077	历史数据回放结束
# 2025-04-26 23:57:09.833077	开始计算逐日盯市盈亏
# 2025-04-26 23:57:09.836065	逐日盯市盈亏计算完成
# 2025-04-26 23:57:09.836065	开始计算策略统计指标
# 2025-04-26 23:57:09.840065	------------------------------
# 2025-04-26 23:57:09.840065	首个交易日：	2022-04-01
# 2025-04-26 23:57:09.840065	最后交易日：	2025-04-25
# 2025-04-26 23:57:09.840065	总交易日：	743
# 2025-04-26 23:57:09.840065	盈利交易日：	50
# 2025-04-26 23:57:09.840065	亏损交易日：	134
# 2025-04-26 23:57:09.840065	起始资金：	1,000,000.00
# 2025-04-26 23:57:09.840065	结束资金：	983,364.47
# 2025-04-26 23:57:09.840065	总收益率：	-1.66%
# 2025-04-26 23:57:09.840065	年化收益：	-0.54%
# 2025-04-26 23:57:09.840065	最大回撤: 	-16,960.49
# 2025-04-26 23:57:09.840065	百分比最大回撤: -1.70%
# 2025-04-26 23:57:09.840065	最大回撤天数: 	1064
# 2025-04-26 23:57:09.840065	总盈亏：	-16,635.53
# 2025-04-26 23:57:09.840065	总手续费：	149.00
# 2025-04-26 23:57:09.840065	总滑点：	10,920.00
# 2025-04-26 23:57:09.840065	总成交金额：	4,966,513.58
# 2025-04-26 23:57:09.840065	总成交笔数：	182
# 2025-04-26 23:57:09.840065	日均盈亏：	-22.39
# 2025-04-26 23:57:09.840065	日均手续费：	0.20
# 2025-04-26 23:57:09.840065	日均滑点：	14.70
# 2025-04-26 23:57:09.840065	日均成交金额：	6,684.41
# 2025-04-26 23:57:09.840065	日均成交笔数：	0.2449528936742934
# 2025-04-26 23:57:09.840065	日均收益率：	-0.00%
# 2025-04-26 23:57:09.840065	收益标准差：	0.02%
# 2025-04-26 23:57:09.840065	Sharpe Ratio：	-1.71
# 2025-04-26 23:57:09.840065	EWM Sharpe：	-2.20
# 2025-04-26 23:57:09.840065	收益回撤比：	-0.98
# 2025-04-26 23:57:09.841065	策略统计指标计算完成
# c:\nero\install\soft\veighna\lib\site-packages\vnpy_ctastrategy\backtesting.py:400: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ewm_sharpe: float = ((ewm_mean - daily_risk_free) / ewm_std)[-1] * np.sqrt(self.annual_days)

# %%
setting = OptimizationSetting()
setting.set_target("sharpe_ratio")
setting.add_parameter("atr_length", 25, 27, 1)
setting.add_parameter("atr_ma_length", 10, 30, 10)

engine.run_ga_optimization(setting)
# Out:
# 2025-04-26 23:57:10.347943	开始执行遗传算法优化
# 2025-04-26 23:57:10.347943	参数优化空间：9
# 2025-04-26 23:57:10.347943	每代族群总数：100
# 2025-04-26 23:57:10.347943	优良筛选个数：80
# 2025-04-26 23:57:10.347943	迭代次数：30
# 2025-04-26 23:57:10.347943	交叉概率：95%
# 2025-04-26 23:57:10.347943	突变概率：5%
# gen	nevals
# 0  	100
# 1  	100
# 2  	100
# 3  	100
# 4  	100
# 5  	100
# 6  	100
# 7  	100
# 8  	100
# 9  	100
# 10 	100
# 11 	100
# 12 	100
# 13 	100
# 14 	100
# 15 	100
# 16 	100
# 17 	100
# 18 	100
# 19 	100
# 20 	100
# 21 	100
# 22 	100
# 23 	100
# 24 	100
# 25 	100
# 26 	100
# 27 	100
# 28 	100
# 29 	100
# 30 	100
# 2025-04-26 23:57:13.462657	遗传算法优化完成，耗时3秒
# 2025-04-26 23:57:13.500665	参数：{'atr_length': 26, 'atr_ma_length': 30}, 目标：-1.114295907510667
# 2025-04-26 23:57:13.500665	参数：{'atr_length': 25, 'atr_ma_length': 30}, 目标：-1.114295907510667
# 2025-04-26 23:57:13.500665	参数：{'atr_length': 27, 'atr_ma_length': 30}, 目标：-1.114295907510667
# 2025-04-26 23:57:13.500665	参数：{'atr_length': 26, 'atr_ma_length': 20}, 目标：-1.1474738964572317
# 2025-04-26 23:57:13.500665	参数：{'atr_length': 25, 'atr_ma_length': 20}, 目标：-1.1591267533474408
# 2025-04-26 23:57:13.500665	参数：{'atr_length': 27, 'atr_ma_length': 20}, 目标：-1.2733285929829894
# 2025-04-26 23:57:13.500665	参数：{'atr_length': 25, 'atr_ma_length': 10}, 目标：-1.6304570601795416
# 2025-04-26 23:57:13.500665	参数：{'atr_length': 26, 'atr_ma_length': 10}, 目标：-1.7237699592927396
# 2025-04-26 23:57:13.500665	参数：{'atr_length': 27, 'atr_ma_length': 10}, 目标：-1.7296589000083362
# [({'atr_length': 26, 'atr_ma_length': 30},
#   -1.114295907510667,
#   {'start_date': datetime.date(2022, 4, 1),
#    'end_date': datetime.date(2025, 4, 25),
#    'total_days': 743,
#    'profit_days': 60,
#    'loss_days': 128,
#    'capital': 1000000,
#    'end_balance': 989417.2228205504,
#    'max_drawdown': -10731.702969449572,
#    'max_ddpercent': -1.0731702969449572,
#    'max_drawdown_duration': 1068,
#    'total_net_pnl': -10582.777179449542,
#    'daily_net_pnl': -14.243307105584847,
#    'total_commission': 149.8893337194251,
#    'daily_commission': 0.2017353078323353,
#    'total_slippage': 11160.0,
#    'daily_slippage': 15.020188425302827,
#    'total_turnover': 4996311.123980837,
#    'daily_turnover': 6724.510261077842,
#    'total_trade_count': 186,
#    'daily_trade_count': 0.2503364737550471,
#    'total_return': -1.0582777179449554,
#    'annual_return': -0.34183937053403674,
#    'daily_return': -0.001431920996190814,
#    'return_std': 0.019907840041236684,
#    'sharpe_ratio': -1.114295907510667,
#    'ewm_sharpe': -1.3499480534772048,
#    'return_drawdown_ratio': -0.9861228184917182}),
#  ({'atr_length': 25, 'atr_ma_length': 30},
#   -1.114295907510667,
#   {'start_date': datetime.date(2022, 4, 1),
#    'end_date': datetime.date(2025, 4, 25),
#    'total_days': 743,
#    'profit_days': 60,
#    'loss_days': 128,
#    'capital': 1000000,
#    'end_balance': 989417.2228205504,
#    'max_drawdown': -10731.702969449572,
#    'max_ddpercent': -1.0731702969449572,
#    'max_drawdown_duration': 1068,
#    'total_net_pnl': -10582.777179449542,
#    'daily_net_pnl': -14.243307105584847,
#    'total_commission': 149.8893337194251,
#    'daily_commission': 0.2017353078323353,
#    'total_slippage': 11160.0,
#    'daily_slippage': 15.020188425302827,
#    'total_turnover': 4996311.123980837,
#    'daily_turnover': 6724.510261077842,
#    'total_trade_count': 186,
#    'daily_trade_count': 0.2503364737550471,
#    'total_return': -1.0582777179449554,
#    'annual_return': -0.34183937053403674,
#    'daily_return': -0.001431920996190814,
#    'return_std': 0.019907840041236684,
#    'sharpe_ratio': -1.114295907510667,
#    'ewm_sharpe': -1.3499480534772048,
#    'return_drawdown_ratio': -0.9861228184917182}),
#  ({'atr_length': 27, 'atr_ma_length': 30},
#   -1.114295907510667,
#   {'start_date': datetime.date(2022, 4, 1),
#    'end_date': datetime.date(2025, 4, 25),
#    'total_days': 743,
#    'profit_days': 60,
#    'loss_days': 128,
#    'capital': 1000000,
#    'end_balance': 989417.2228205504,
#    'max_drawdown': -10731.702969449572,
#    'max_ddpercent': -1.0731702969449572,
#    'max_drawdown_duration': 1068,
#    'total_net_pnl': -10582.777179449542,
#    'daily_net_pnl': -14.243307105584847,
#    'total_commission': 149.8893337194251,
#    'daily_commission': 0.2017353078323353,
#    'total_slippage': 11160.0,
#    'daily_slippage': 15.020188425302827,
#    'total_turnover': 4996311.123980837,
#    'daily_turnover': 6724.510261077842,
#    'total_trade_count': 186,
#    'daily_trade_count': 0.2503364737550471,
#    'total_return': -1.0582777179449554,
#    'annual_return': -0.34183937053403674,
#    'daily_return': -0.001431920996190814,
#    'return_std': 0.019907840041236684,
#    'sharpe_ratio': -1.114295907510667,
#    'ewm_sharpe': -1.3499480534772048,
#    'return_drawdown_ratio': -0.9861228184917182}),
#  ({'atr_length': 26, 'atr_ma_length': 20},
#   -1.1474738964572317,
#   {'start_date': datetime.date(2022, 4, 1),
#    'end_date': datetime.date(2025, 4, 25),
#    'total_days': 743,
#    'profit_days': 59,
#    'loss_days': 133,
#    'capital': 1000000,
#    'end_balance': 988588.6465340536,
#    'max_drawdown': -11411.353465946391,
#    'max_ddpercent': -1.1411353465946392,
#    'max_drawdown_duration': 1120,
#    'total_net_pnl': -11411.35346594643,
#    'daily_net_pnl': -15.358483803427227,
#    'total_commission': 154.08341195728423,
#    'daily_commission': 0.2073800968469505,
#    'total_slippage': 11340.0,
#    'daily_slippage': 15.262449528936743,
#    'total_turnover': 5136113.731909475,
#    'daily_turnover': 6912.669894898351,
#    'total_trade_count': 189,
#    'daily_trade_count': 0.2543741588156124,
#    'total_return': -1.141135346594635,
#    'annual_return': -0.3686036112822509,
#    'daily_return': -0.0015446786760689767,
#    'return_std': 0.020854556451794095,
#    'sharpe_ratio': -1.1474738964572317,
#    'ewm_sharpe': -1.2972931072532767,
#    'return_drawdown_ratio': -0.9999999999999963}),
#  ({'atr_length': 25, 'atr_ma_length': 20},
#   -1.1591267533474408,
#   {'start_date': datetime.date(2022, 4, 1),
#    'end_date': datetime.date(2025, 4, 25),
#    'total_days': 743,
#    'profit_days': 58,
#    'loss_days': 132,
#    'capital': 1000000,
#    'end_balance': 988503.5931440536,
#    'max_drawdown': -11496.406855946407,
#    'max_ddpercent': -1.1496406855946406,
#    'max_drawdown_duration': 1120,
#    'total_net_pnl': -11496.406855946429,
#    'daily_net_pnl': -15.47295673747837,
#    'total_commission': 152.13680195728423,
#    'daily_commission': 0.20476016414170153,
#    'total_slippage': 11220.0,
#    'daily_slippage': 15.100942126514132,
#    'total_turnover': 5071226.731909475,
#    'daily_turnover': 6825.338804723386,
#    'total_trade_count': 187,
#    'daily_trade_count': 0.25168236877523553,
#    'total_return': -1.149640685594644,
#    'annual_return': -0.37135096169948123,
#    'daily_return': -0.0015562586045947983,
#    'return_std': 0.020799670581603712,
#    'sharpe_ratio': -1.1591267533474408,
#    'ewm_sharpe': -1.3337536559316372,
#    'return_drawdown_ratio': -1.0000000000000029}),
#  ({'atr_length': 27, 'atr_ma_length': 20},
#   -1.2733285929829894,
#   {'start_date': datetime.date(2022, 4, 1),
#    'end_date': datetime.date(2025, 4, 25),
#    'total_days': 743,
#    'profit_days': 58,
#    'loss_days': 138,
#    'capital': 1000000,
#    'end_balance': 987298.6638878089,
#    'max_drawdown': -12701.336112191086,
#    'max_ddpercent': -1.2701336112191086,
#    'max_drawdown_duration': 1120,
#    'total_net_pnl': -12701.336112191086,
#    'daily_net_pnl': -17.094665023137395,
#    'total_commission': 156.73597360663183,
#    'daily_commission': 0.21095016636155026,
#    'total_slippage': 11580.0,
#    'daily_slippage': 15.585464333781966,
#    'total_turnover': 5224532.453554394,
#    'daily_turnover': 7031.672212051674,
#    'total_trade_count': 193,
#    'daily_trade_count': 0.2597577388963661,
#    'total_return': -1.2701336112191042,
#    'annual_return': -0.41027196055529613,
#    'daily_return': -0.0017204155672594678,
#    'return_std': 0.020931410406617387,
#    'sharpe_ratio': -1.2733285929829894,
#    'ewm_sharpe': -1.493771059564178,
#    'return_drawdown_ratio': -0.9999999999999966}),
#  ({'atr_length': 25, 'atr_ma_length': 10},
#   -1.6304570601795416,
#   {'start_date': datetime.date(2022, 4, 1),
#    'end_date': datetime.date(2025, 4, 25),
#    'total_days': 743,
#    'profit_days': 49,
#    'loss_days': 125,
#    'capital': 1000000,
#    'end_balance': 984189.9423590344,
#    'max_drawdown': -16135.016410965589,
#    'max_ddpercent': -1.613501641096559,
#    'max_drawdown_duration': 1064,
#    'total_net_pnl': -15810.05764096558,
#    'daily_net_pnl': -21.278677847867538,
#    'total_commission': 140.4067480561497,
#    'daily_commission': 0.18897274300962275,
#    'total_slippage': 10320.0,
#    'daily_slippage': 13.88963660834455,
#    'total_turnover': 4680224.93520499,
#    'daily_turnover': 6299.091433654092,
#    'total_trade_count': 172,
#    'daily_trade_count': 0.23149394347240915,
#    'total_return': -1.5810057640965547,
#    'annual_return': -0.5106882683488199,
#    'daily_return': -0.002144868062619646,
#    'return_std': 0.020379655470161986,
#    'sharpe_ratio': -1.6304570601795416,
#    'ewm_sharpe': -2.100761984972431,
#    'return_drawdown_ratio': -0.9798600285414525}),
#  ({'atr_length': 26, 'atr_ma_length': 10},
#   -1.7237699592927396,
#   {'start_date': datetime.date(2022, 4, 1),
#    'end_date': datetime.date(2025, 4, 25),
#    'total_days': 743,
#    'profit_days': 50,
#    'loss_days': 128,
#    'capital': 1000000,
#    'end_balance': 982982.2576746801,
#    'max_drawdown': -17342.701095319935,
#    'max_ddpercent': -1.7342701095319935,
#    'max_drawdown_duration': 1064,
#    'total_net_pnl': -17017.742325319952,
#    'daily_net_pnl': -22.904094650497917,
#    'total_commission': 143.1053275744515,
#    'daily_commission': 0.19260474774488762,
#    'total_slippage': 10560.0,
#    'daily_slippage': 14.212651413189771,
#    'total_turnover': 4770177.585815052,
#    'daily_turnover': 6420.158258162923,
#    'total_trade_count': 176,
#    'daily_trade_count': 0.23687752355316286,
#    'total_return': -1.701774232531994,
#    'annual_return': -0.5496982716119496,
#    'daily_return': -0.002310122228656413,
#    'return_std': 0.020761621632995202,
#    'sharpe_ratio': -1.7237699592927396,
#    'ewm_sharpe': -2.1196317888351857,
#    'return_drawdown_ratio': -0.9812625052917687}),
#  ({'atr_length': 27, 'atr_ma_length': 10},
#   -1.7296589000083362,
#   {'start_date': datetime.date(2022, 4, 1),
#    'end_date': datetime.date(2025, 4, 25),
#    'total_days': 743,
#    'profit_days': 51,
#    'loss_days': 129,
#    'capital': 1000000,
#    'end_balance': 982874.303642964,
#    'max_drawdown': -17450.655127036036,
#    'max_ddpercent': -1.7450655127036037,
#    'max_drawdown_duration': 1064,
#    'total_net_pnl': -17125.696357036064,
#    'daily_net_pnl': -23.049389444193896,
#    'total_commission': 144.80560010019474,
#    'daily_commission': 0.19489313607024863,
#    'total_slippage': 10680.0,
#    'daily_slippage': 14.374158815612383,
#    'total_turnover': 4826853.336673159,
#    'daily_turnover': 6496.437869008289,
#    'total_trade_count': 178,
#    'daily_trade_count': 0.2395693135935397,
#    'total_return': -1.712569635703598,
#    'annual_return': -0.5531853466606508,
#    'daily_return': -0.002324904059304736,
#    'return_std': 0.020823330433934382,
#    'sharpe_ratio': -1.7296589000083362,
#    'ewm_sharpe': -2.1209010927373617,
#    'return_drawdown_ratio': -0.9813784200286783})]

# %%
engine.run_bf_optimization(setting)
# Out:
# 2025-04-26 23:57:13.513668	开始执行穷举算法优化
# 2025-04-26 23:57:13.513668	参数优化空间：9
# 100%|██████████| 9/9 [00:00<00:00,  9.31it/s]
# 2025-04-26 23:57:14.517890	穷举算法优化完成，耗时1秒
# 2025-04-26 23:57:14.615444	参数：{'atr_length': 25, 'atr_ma_length': 30}, 目标：-1.114295907510667
# 2025-04-26 23:57:14.615444	参数：{'atr_length': 26, 'atr_ma_length': 30}, 目标：-1.114295907510667
# 2025-04-26 23:57:14.615444	参数：{'atr_length': 27, 'atr_ma_length': 30}, 目标：-1.114295907510667
# 2025-04-26 23:57:14.615444	参数：{'atr_length': 26, 'atr_ma_length': 20}, 目标：-1.1474738964572317
# 2025-04-26 23:57:14.615444	参数：{'atr_length': 25, 'atr_ma_length': 20}, 目标：-1.1591267533474408
# 2025-04-26 23:57:14.615444	参数：{'atr_length': 27, 'atr_ma_length': 20}, 目标：-1.2733285929829894
# 2025-04-26 23:57:14.615444	参数：{'atr_length': 25, 'atr_ma_length': 10}, 目标：-1.6304570601795416
# 2025-04-26 23:57:14.615444	参数：{'atr_length': 26, 'atr_ma_length': 10}, 目标：-1.7237699592927396
# 2025-04-26 23:57:14.615444	参数：{'atr_length': 27, 'atr_ma_length': 10}, 目标：-1.7296589000083362
# [({'atr_length': 25, 'atr_ma_length': 30},
#   -1.114295907510667,
#   {'start_date': datetime.date(2022, 4, 1),
#    'end_date': datetime.date(2025, 4, 25),
#    'total_days': 743,
#    'profit_days': 60,
#    'loss_days': 128,
#    'capital': 1000000,
#    'end_balance': 989417.2228205504,
#    'max_drawdown': -10731.702969449572,
#    'max_ddpercent': -1.0731702969449572,
#    'max_drawdown_duration': 1068,
#    'total_net_pnl': -10582.777179449542,
#    'daily_net_pnl': -14.243307105584847,
#    'total_commission': 149.8893337194251,
#    'daily_commission': 0.2017353078323353,
#    'total_slippage': 11160.0,
#    'daily_slippage': 15.020188425302827,
#    'total_turnover': 4996311.123980837,
#    'daily_turnover': 6724.510261077842,
#    'total_trade_count': 186,
#    'daily_trade_count': 0.2503364737550471,
#    'total_return': -1.0582777179449554,
#    'annual_return': -0.34183937053403674,
#    'daily_return': -0.001431920996190814,
#    'return_std': 0.019907840041236684,
#    'sharpe_ratio': -1.114295907510667,
#    'ewm_sharpe': -1.3499480534772048,
#    'return_drawdown_ratio': -0.9861228184917182}),
#  ({'atr_length': 26, 'atr_ma_length': 30},
#   -1.114295907510667,
#   {'start_date': datetime.date(2022, 4, 1),
#    'end_date': datetime.date(2025, 4, 25),
#    'total_days': 743,
#    'profit_days': 60,
#    'loss_days': 128,
#    'capital': 1000000,
#    'end_balance': 989417.2228205504,
#    'max_drawdown': -10731.702969449572,
#    'max_ddpercent': -1.0731702969449572,
#    'max_drawdown_duration': 1068,
#    'total_net_pnl': -10582.777179449542,
#    'daily_net_pnl': -14.243307105584847,
#    'total_commission': 149.8893337194251,
#    'daily_commission': 0.2017353078323353,
#    'total_slippage': 11160.0,
#    'daily_slippage': 15.020188425302827,
#    'total_turnover': 4996311.123980837,
#    'daily_turnover': 6724.510261077842,
#    'total_trade_count': 186,
#    'daily_trade_count': 0.2503364737550471,
#    'total_return': -1.0582777179449554,
#    'annual_return': -0.34183937053403674,
#    'daily_return': -0.001431920996190814,
#    'return_std': 0.019907840041236684,
#    'sharpe_ratio': -1.114295907510667,
#    'ewm_sharpe': -1.3499480534772048,
#    'return_drawdown_ratio': -0.9861228184917182}),
#  ({'atr_length': 27, 'atr_ma_length': 30},
#   -1.114295907510667,
#   {'start_date': datetime.date(2022, 4, 1),
#    'end_date': datetime.date(2025, 4, 25),
#    'total_days': 743,
#    'profit_days': 60,
#    'loss_days': 128,
#    'capital': 1000000,
#    'end_balance': 989417.2228205504,
#    'max_drawdown': -10731.702969449572,
#    'max_ddpercent': -1.0731702969449572,
#    'max_drawdown_duration': 1068,
#    'total_net_pnl': -10582.777179449542,
#    'daily_net_pnl': -14.243307105584847,
#    'total_commission': 149.8893337194251,
#    'daily_commission': 0.2017353078323353,
#    'total_slippage': 11160.0,
#    'daily_slippage': 15.020188425302827,
#    'total_turnover': 4996311.123980837,
#    'daily_turnover': 6724.510261077842,
#    'total_trade_count': 186,
#    'daily_trade_count': 0.2503364737550471,
#    'total_return': -1.0582777179449554,
#    'annual_return': -0.34183937053403674,
#    'daily_return': -0.001431920996190814,
#    'return_std': 0.019907840041236684,
#    'sharpe_ratio': -1.114295907510667,
#    'ewm_sharpe': -1.3499480534772048,
#    'return_drawdown_ratio': -0.9861228184917182}),
#  ({'atr_length': 26, 'atr_ma_length': 20},
#   -1.1474738964572317,
#   {'start_date': datetime.date(2022, 4, 1),
#    'end_date': datetime.date(2025, 4, 25),
#    'total_days': 743,
#    'profit_days': 59,
#    'loss_days': 133,
#    'capital': 1000000,
#    'end_balance': 988588.6465340536,
#    'max_drawdown': -11411.353465946391,
#    'max_ddpercent': -1.1411353465946392,
#    'max_drawdown_duration': 1120,
#    'total_net_pnl': -11411.35346594643,
#    'daily_net_pnl': -15.358483803427227,
#    'total_commission': 154.08341195728423,
#    'daily_commission': 0.2073800968469505,
#    'total_slippage': 11340.0,
#    'daily_slippage': 15.262449528936743,
#    'total_turnover': 5136113.731909475,
#    'daily_turnover': 6912.669894898351,
#    'total_trade_count': 189,
#    'daily_trade_count': 0.2543741588156124,
#    'total_return': -1.141135346594635,
#    'annual_return': -0.3686036112822509,
#    'daily_return': -0.0015446786760689767,
#    'return_std': 0.020854556451794095,
#    'sharpe_ratio': -1.1474738964572317,
#    'ewm_sharpe': -1.2972931072532767,
#    'return_drawdown_ratio': -0.9999999999999963}),
#  ({'atr_length': 25, 'atr_ma_length': 20},
#   -1.1591267533474408,
#   {'start_date': datetime.date(2022, 4, 1),
#    'end_date': datetime.date(2025, 4, 25),
#    'total_days': 743,
#    'profit_days': 58,
#    'loss_days': 132,
#    'capital': 1000000,
#    'end_balance': 988503.5931440536,
#    'max_drawdown': -11496.406855946407,
#    'max_ddpercent': -1.1496406855946406,
#    'max_drawdown_duration': 1120,
#    'total_net_pnl': -11496.406855946429,
#    'daily_net_pnl': -15.47295673747837,
#    'total_commission': 152.13680195728423,
#    'daily_commission': 0.20476016414170153,
#    'total_slippage': 11220.0,
#    'daily_slippage': 15.100942126514132,
#    'total_turnover': 5071226.731909475,
#    'daily_turnover': 6825.338804723386,
#    'total_trade_count': 187,
#    'daily_trade_count': 0.25168236877523553,
#    'total_return': -1.149640685594644,
#    'annual_return': -0.37135096169948123,
#    'daily_return': -0.0015562586045947983,
#    'return_std': 0.020799670581603712,
#    'sharpe_ratio': -1.1591267533474408,
#    'ewm_sharpe': -1.3337536559316372,
#    'return_drawdown_ratio': -1.0000000000000029}),
#  ({'atr_length': 27, 'atr_ma_length': 20},
#   -1.2733285929829894,
#   {'start_date': datetime.date(2022, 4, 1),
#    'end_date': datetime.date(2025, 4, 25),
#    'total_days': 743,
#    'profit_days': 58,
#    'loss_days': 138,
#    'capital': 1000000,
#    'end_balance': 987298.6638878089,
#    'max_drawdown': -12701.336112191086,
#    'max_ddpercent': -1.2701336112191086,
#    'max_drawdown_duration': 1120,
#    'total_net_pnl': -12701.336112191086,
#    'daily_net_pnl': -17.094665023137395,
#    'total_commission': 156.73597360663183,
#    'daily_commission': 0.21095016636155026,
#    'total_slippage': 11580.0,
#    'daily_slippage': 15.585464333781966,
#    'total_turnover': 5224532.453554394,
#    'daily_turnover': 7031.672212051674,
#    'total_trade_count': 193,
#    'daily_trade_count': 0.2597577388963661,
#    'total_return': -1.2701336112191042,
#    'annual_return': -0.41027196055529613,
#    'daily_return': -0.0017204155672594678,
#    'return_std': 0.020931410406617387,
#    'sharpe_ratio': -1.2733285929829894,
#    'ewm_sharpe': -1.493771059564178,
#    'return_drawdown_ratio': -0.9999999999999966}),
#  ({'atr_length': 25, 'atr_ma_length': 10},
#   -1.6304570601795416,
#   {'start_date': datetime.date(2022, 4, 1),
#    'end_date': datetime.date(2025, 4, 25),
#    'total_days': 743,
#    'profit_days': 49,
#    'loss_days': 125,
#    'capital': 1000000,
#    'end_balance': 984189.9423590344,
#    'max_drawdown': -16135.016410965589,
#    'max_ddpercent': -1.613501641096559,
#    'max_drawdown_duration': 1064,
#    'total_net_pnl': -15810.05764096558,
#    'daily_net_pnl': -21.278677847867538,
#    'total_commission': 140.4067480561497,
#    'daily_commission': 0.18897274300962275,
#    'total_slippage': 10320.0,
#    'daily_slippage': 13.88963660834455,
#    'total_turnover': 4680224.93520499,
#    'daily_turnover': 6299.091433654092,
#    'total_trade_count': 172,
#    'daily_trade_count': 0.23149394347240915,
#    'total_return': -1.5810057640965547,
#    'annual_return': -0.5106882683488199,
#    'daily_return': -0.002144868062619646,
#    'return_std': 0.020379655470161986,
#    'sharpe_ratio': -1.6304570601795416,
#    'ewm_sharpe': -2.100761984972431,
#    'return_drawdown_ratio': -0.9798600285414525}),
#  ({'atr_length': 26, 'atr_ma_length': 10},
#   -1.7237699592927396,
#   {'start_date': datetime.date(2022, 4, 1),
#    'end_date': datetime.date(2025, 4, 25),
#    'total_days': 743,
#    'profit_days': 50,
#    'loss_days': 128,
#    'capital': 1000000,
#    'end_balance': 982982.2576746801,
#    'max_drawdown': -17342.701095319935,
#    'max_ddpercent': -1.7342701095319935,
#    'max_drawdown_duration': 1064,
#    'total_net_pnl': -17017.742325319952,
#    'daily_net_pnl': -22.904094650497917,
#    'total_commission': 143.1053275744515,
#    'daily_commission': 0.19260474774488762,
#    'total_slippage': 10560.0,
#    'daily_slippage': 14.212651413189771,
#    'total_turnover': 4770177.585815052,
#    'daily_turnover': 6420.158258162923,
#    'total_trade_count': 176,
#    'daily_trade_count': 0.23687752355316286,
#    'total_return': -1.701774232531994,
#    'annual_return': -0.5496982716119496,
#    'daily_return': -0.002310122228656413,
#    'return_std': 0.020761621632995202,
#    'sharpe_ratio': -1.7237699592927396,
#    'ewm_sharpe': -2.1196317888351857,
#    'return_drawdown_ratio': -0.9812625052917687}),
#  ({'atr_length': 27, 'atr_ma_length': 10},
#   -1.7296589000083362,
#   {'start_date': datetime.date(2022, 4, 1),
#    'end_date': datetime.date(2025, 4, 25),
#    'total_days': 743,
#    'profit_days': 51,
#    'loss_days': 129,
#    'capital': 1000000,
#    'end_balance': 982874.303642964,
#    'max_drawdown': -17450.655127036036,
#    'max_ddpercent': -1.7450655127036037,
#    'max_drawdown_duration': 1064,
#    'total_net_pnl': -17125.696357036064,
#    'daily_net_pnl': -23.049389444193896,
#    'total_commission': 144.80560010019474,
#    'daily_commission': 0.19489313607024863,
#    'total_slippage': 10680.0,
#    'daily_slippage': 14.374158815612383,
#    'total_turnover': 4826853.336673159,
#    'daily_turnover': 6496.437869008289,
#    'total_trade_count': 178,
#    'daily_trade_count': 0.2395693135935397,
#    'total_return': -1.712569635703598,
#    'annual_return': -0.5531853466606508,
#    'daily_return': -0.002324904059304736,
#    'return_std': 0.020823330433934382,
#    'sharpe_ratio': -1.7296589000083362,
#    'ewm_sharpe': -2.1209010927373617,
#    'return_drawdown_ratio': -0.9813784200286783})]
